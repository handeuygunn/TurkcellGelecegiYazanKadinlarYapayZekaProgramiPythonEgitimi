# %% [markdown]
# Bir öğrenci yönetim sistemi için aşağıdaki veri yapısı verilmiştir:
#
# students = [ {"name": "Ali", "grades": {"math": 85, "physics": 90, "history": 78}}, {"name": "Ayşe", "grades": {"math": 92, "physics": 88, "history": 95}}, {"name": "Mehmet", "grades": {"math": 75, "physics": 80, "history": 85}}, {"name": "Zeynep", "grades": {"math": 90, "physics": 85, "history": 88}}, ] Yapılması gerekenler: 1.En yüksek matematik notuna sahip öğrencinin adını bulun. 2.Tüm derslerin ortalama notlarını içeren bir sözlük oluşturun. 3.Ortalama notu 85'in üzerinde olan öğrencileri bir liste halinde döndürün. Bunu en verimli şekilde Python kodu ile nasıl yaparsınız?
