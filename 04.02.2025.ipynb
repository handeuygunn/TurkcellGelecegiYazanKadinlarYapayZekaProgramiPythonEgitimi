# %% [markdown]
# 4 Şubat 2025

# %%
cities = ["Ankara", "İstanbul", "izmir", "Bursa"]
print("Şehirler", cities)
# Out:
# Şehirler ['Ankara', 'İstanbul', 'izmir', 'Bursa']

# %%
for city in cities:
    print(city)
# Out:
# Ankara
# İstanbul
# izmir
# Bursa

# %%
cities.append("Antalya")
print(cities)
# Out:
# ['Ankara', 'İstanbul', 'izmir', 'Bursa', 'Antalya']

# %%
cities.insert(0, "Antalya")
print(cities)
# Out:
# ['Antalya', 'Ankara', 'İstanbul', 'izmir', 'Bursa', 'Antalya']

# %%
cities.remove("İstanbul")
print(cities)
# Out:
# ['Antalya', 'Ankara', 'izmir', 'Bursa', 'Antalya']

# %%
cities.pop(4)
print(cities)
# Out:
# ['Antalya']

# %%
print(cities[2])
# Out:
# izmir

# %%
print(cities[-1])
# Out:
# Bursa

# %%
print(cities)
# Out:
# ['Antalya']

# %%
cities.append("Bursa")
print(cities)
# Out:
# ['Antalya', 'Bursa', 'Bursa']

# %%
cities.append("Van")

# %%
cities
# Out:
# ['Antalya', 'Bursa', 'Bursa', 'Van']

# %%
newCities = cities[:]
newCities
# Out:
# ['Antalya', 'Bursa', 'Bursa', 'Van']

# %%
newCities[1] = "Erzincan"
cities[1]
# Out:
# 'Bursa'

# %%
newCities2 = cities[1:3]
newCities2
# Out:
# ['Bursa', 'Bursa']

# %%
cities
# Out:
# ['Antalya', 'Bursa', 'Bursa', 'Van']

# %%
newCities3 = cities
newCities3
# Out:
# ['Antalya', 'Bursa', 'Bursa', 'Van']

# %%
newCities3[1] = "Kocaeli"
newCities3
# Out:
# ['Antalya', 'Kocaeli', 'Bursa', 'Van']

# %%
newCities4 = cities.copy()
newCities4
# Out:
# ['Antalya', 'Kocaeli', 'Bursa', 'Van']

# %%
newCities4[1] = "Mersin"
cities[1]
# Out:
# 'Kocaeli'

# %%
countriesAndCapitals = {"Turkiye": "Ankara", "Fransa": "Paris", "Almanya": "Berlin" }
countriesAndCapitals
# Out:
# {'Turkiye': 'Ankara', 'Fransa': 'Paris', 'Almanya': 'Berlin'}

# %%
countriesAndCapitals["Turkiye"]
# Out:
# 'Ankara'

# %%
del countriesAndCapitals["Fransa"]
countriesAndCapitals
# Out:
# {'Turkiye': 'Ankara', 'Almanya': 'Berlin'}

# %%
countriesAndCapitals.get("Türkiye")

# %%
countriesAndCapitals.keys()
# Out:
# dict_keys(['Turkiye', 'Almanya'])

# %%
countriesAndCapitals.values()
# Out:
# dict_values(['Ankara', 'Berlin'])

# %%
for key, value in countriesAndCapitals.items():
    print(key, value)
# Out:
# Turkiye Ankara
# Almanya Berlin

# %%
personalInfo = {"name": "Engin", "surname": "Demiroğ", "age": 25}
personalInfo
# Out:
# {'name': 'Engin', 'surname': 'Demiroğ', 'age': 25}

# %%
personalInfo.keys()
# Out:
# dict_keys(['name', 'surname', 'age'])
